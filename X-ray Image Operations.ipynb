# %%
# Resize/Scaling X-ray Image

import cv2
import numpy as np

img=cv2.imread(r"C:\Users\Asus\Desktop\NORMAL-1110860-0001.jpeg")
res=cv2.resize(img, (500, 500), interpolation=cv2.INTER_AREA)
cv2.imshow('resize', res)
cv2.waitKey(0)  
cv2.destroyAllWindows()

# %%
# Rotate X-ray Image

import cv2
import numpy as np

img=cv2.imread(r"C:\Users\Asus\Desktop\NORMAL-1110860-0001.jpeg")
rotated=cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
cv2.imshow('rotated image', rotated)
#movewindows is used for showing positon of output screen
cv2.moveWindow('rotated image', 100, 50)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Translation X-ray Image


import cv2
import numpy as np

img=cv2.imread(r"C:\Users\Asus\Desktop\NORMAL-1110860-0001.jpeg")
height, width=img.shape[:2]
quartex_height, quartex_width=height/4, width/4

t=np.float32([[1,0, quartex_width], [0, 1, quartex_height]])
translations=cv2.warpAffine(img, t, (height, width))

cv2.imshow('transaltion', translations)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Bluring X-ray Image

import cv2
from matplotlib import pyplot as plt

img=cv2.imread(r"C:\Users\Asus\Desktop\NORMAL-1110860-0001.jpeg")

blur=cv2.blur(img,(10, 15))

plt.subplot(121), plt.imshow(img), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(blur), plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# Remove Noise form X-ray image Colored image

import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(r"C:\Users\Asus\Desktop\NORMAL-1110860-0001.jpeg")
dst = cv.fastNlMeansDenoisingColored(img,None,10,10,7,21)
plt.subplot(121),plt.imshow(img), plt.title('Original Image')
plt.subplot(122),plt.imshow(dst), plt.title('Without Noice Image')
plt.show()

# %%
# Remove Noise form X-ray image Grayscale Image

import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(r"C:\Users\Asus\Desktop\NORMAL-1110860-0001.jpeg")
dst = cv.fastNlMeansDenoising(img,None,10,7,21)
plt.subplot(121),plt.imshow(img), plt.title('Original Image')
plt.subplot(122),plt.imshow(dst), plt.title('Without Noice Image')
plt.show()

# %%
# Avaraging  X-ray Image

# importing opencv CV2 module
import cv2 
  
# bat.jpg is the batman image.
img = cv2.imread(r"C:\Users\Asus\Desktop\NORMAL-1110860-0001.jpeg")
   
# make sure that you have saved it in the same folder
# Averaging
# You can change the kernel size as you want
avging = cv2.blur(img,(10,10))
   
cv2.imshow('Averaging',avging)

  
# Gaussian Blurring
# Again, you can change the kernel size
gausBlur = cv2.GaussianBlur(img, (5,5),0) 
cv2.imshow('Gaussian Blurring', gausBlur)

  
# Median blurring
medBlur = cv2.medianBlur(img,5)
cv2.imshow('Media Blurring', medBlur)

  
# Bilateral Filtering
bilFilter = cv2.bilateralFilter(img,9,75,75)
cv2.imshow('Bilateral Filtering', bilFilter)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Contrast X-ray image 

# import the required library
import cv2

# read the input image
image = cv2.imread(r"C:\Users\Asus\Desktop\NORMAL-1110860-0001.jpeg")

# define the alpha and beta
alpha = 1.0 # Contrast control
beta = 5 # Brightness control

# call convertScaleAbs function
adjusted = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)


cv2.imshow('Oringinal Image', image)
# display the output image
cv2.imshow('adjusted', adjusted)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# Access Multiple images of an flolder 

import cv2
import glob

path=glob.glob(r'C:\Users\Asus\Desktop\Bronchitis Project\*.jpeg')

for file in path:
    img = cv2.imread(file)
    cv2.imshow('images', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# Access Multiple images of an flolder and resize them as 500px width and 500px heights

import cv2
import glob

path=glob.glob(r'C:\Users\Asus\Desktop\Bronchitis Project\*.jpeg')

for file in path:
    img = cv2.imread(file)
    res=cv2.resize(img, (500, 500), interpolation=cv2.INTER_AREA)
    cv2.imshow('resized images', res)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# Access Multiple images of an flolder and Denoising all images

import cv2
import glob

path=glob.glob(r'C:\Users\Asus\Desktop\Bronchitis Project\*.jpeg')

for file in path:
    img = cv2.imread(file)
    res=cv2.resize(img, (500, 500), interpolation=cv2.INTER_AREA)
    dst = cv2.fastNlMeansDenoising(res, None,10,7,21)
    cv2.imshow('resized images', dst)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# All Operations perform 

import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np

# read images
path=glob.glob(r'C:\Users\Asus\Desktop\Bronchitis Project\*.jpeg')

for file in path:
    img = cv2.imread(file)
    #Crop image
    crop=img[80:250, 40:400]
    #Resize image
    resize = cv2.resize(img,(150, 150))
    #Rotation of images
    rotated = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    #Translation images
    height, width = img.shape[:2]
    quartex_height, quartex_width = height/4, width/4
    
    T = np.float32([[1, 0, quartex_width], [0, 1, quartex_height]])
    translation = cv2.warpAffine(img, T, (height, width))
    
    #Obtain histogram and histogram equalistion 
    
    histr = cv2.calcHist([img], [0], None, [250], [0, 256])
    cv2.imshow('images original', img)
    plt.plot(histr)
    plt.show()
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# Access Multiple images of an flolder and Denoising all images

import cv2
import glob

path=glob.glob(r'C:\Users\Asus\Desktop\Bronchitis Project\*.jpeg')

for file in path:
    img = cv2.imread(file)
    res=cv2.resize(img, (500, 500), interpolation=cv2.INTER_AREA)
    # Remove noise using a median filter
    dst= cv2.medianBlur(res, 11)
    cv2.imshow('resized images', dst)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# Remove Noise form X-ray image Colored image

import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(r"C:\Users\Asus\Desktop\NORMAL-1110860-0001.jpeg")
dst = cv.medianBlur(img,None,10,10,7,21)
plt.subplot(121),plt.imshow(img), plt.title('Original Image')
plt.subplot(122),plt.imshow(dst), plt.title('Without Noice Image')
plt.show()
